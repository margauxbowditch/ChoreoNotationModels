# %%
import os

# Set the CUDA_VISIBLE_DEVICES environment variable
os.environ["CUDA_VISIBLE_DEVICES"] = "0"  # Replace with the GPU index you want to use

# Confirm the selected GPU
print(f"Using GPU {os.environ['CUDA_VISIBLE_DEVICES']} for the experiment.")
# Out:
# Using GPU 0 for the experiment.

# %%
#imports
import matplotlib.pyplot as plt
import h5py
import numpy as np
import scipy
import seaborn as sns
import math
import json
import tensorflow as tf
import keras as keras
from keras.layers import Input, LSTM, RepeatVector, Dense
from keras.models import Model
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from sklearn.model_selection import train_test_split
# Out:
# 2024-01-07 18:48:17.855493: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
print(keras.__version__)
print(tf.__version__)
# Out:
# 2.13.1
# 2.13.0

# %%
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    # Print the list of available GPUs
    for gpu in gpus:
        print("GPU:", gpu)
else:
    print("No GPU available.")
# Out:
# GPU: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')

# %%
#Prepare Training Data:
path_to_X = "../Normalised/X.npy"
path_to_Y = "../Normalised/Y.npy"
X = np.load(path_to_X)
Y = np.load(path_to_Y)
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state=42)
print(len(X_train))
print(len(X_test))
# Reshape the input and output data for the encoder and decoder
X_train_reshaped = X_train.reshape(X_train.shape[0], X_train.shape[1], 1) # (No of Data, 50) to (No of data, 50,1)
print("X_train_reshaped shape: ", X_train_reshaped.shape)
Y_train_reshaped = Y_train.reshape(Y_train.shape[0], Y_train.shape[1], 1)
print("Y_train_resahped shape: ", Y_train_reshaped.shape)
# Define the input shape for the encoder
input_shape = X_train_reshaped.shape[1:]  # Shape: (sequence_length, 1) # 50,1
print("Input_shape: ", input_shape)
X_test_reshaped = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
Y_test_reshaped = Y_test.reshape(Y_test.shape[0], Y_test.shape[1], 1)
print("X_test_reshaped",X_test_reshaped.shape)
print("Y_test_reshaped",Y_test_reshaped.shape)
# Out:
# 49730
# 12433
# X_train_reshaped shape:  (49730, 50, 1)
# Y_train_resahped shape:  (49730, 81, 1)
# Input_shape:  (50, 1)
# X_test_reshaped (12433, 50, 1)
# Y_test_reshaped (12433, 81, 1)

# %%
# Define the model
def createModel(units, optimizer):        
    # Define the encoder
    encoder_inputs = Input(shape=input_shape)
    encoder_lstm = LSTM(units)(encoder_inputs)
    encoder_model = Model(encoder_inputs, encoder_lstm)
    
    # Define the input shape for the decoder (with units to match encoder LSTM units)
    decoder_inputs = Input(shape=(units,))  # This will serve as the initial state of the decoder LSTM
    decoder_lstm = LSTM(units, return_sequences=True)(RepeatVector(Y_train_reshaped.shape[1])(decoder_inputs))
    decoder_outputs = Dense(1, activation='sigmoid')(decoder_lstm)
    
    # Define the decoder model
    decoder_model = Model(decoder_inputs, decoder_outputs)
    
    # Create the full seq_model model
    seq_model_outputs = decoder_model(encoder_lstm)
    seq_model = Model(encoder_inputs, seq_model_outputs)
    
    # Compile the model
    seq_model.compile(optimizer=optimizer, loss='mean_squared_error', metrics = ['mae'])
    
    # Display the model summary
    seq_model.summary()
    return seq_model

# %%
#Train the model
# Enable logging of device placement
tf.debugging.set_log_device_placement(False)

# Verify the available GPUs
gpus = tf.config.experimental.list_physical_devices('GPU')
print("GPUs:", gpus)
if gpus:
    # Use the first GPU for training
    with tf.device('/GPU:0'):
        save_path = "./Saved_Models_Data/P40_U32_OA/"
        seq_model = createModel(32,'adam')
        early_stopping = EarlyStopping(monitor='val_loss', patience=40, verbose=1)
        mc = ModelCheckpoint(save_path+"best_enc_dec_3.h5", monitor = 'val_loss',mode='min', save_best_only=True, verbose=1)
        history = seq_model.fit(X_train_reshaped, Y_train_reshaped, batch_size=32, epochs=200, validation_split=0.2, callbacks=[early_stopping, mc])
        with open(save_path+'history_3.json','w') as file:
            json.dump(history.history, file)
else:
    print("No GPU available.")
# Out:
# GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# 2024-01-07 18:48:30.660955: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 78946 MB memory:  -> device: 0, name: NVIDIA A100 80GB PCIe, pci bus id: 0000:01:00.0, compute capability: 8.0
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 50, 1)]           0
#
#  lstm (LSTM)                 (None, 32)                4352
#
#  model_1 (Functional)        (None, 81, 1)             8353
#
# =================================================================
# Total params: 12705 (49.63 KB)
# Trainable params: 12705 (49.63 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/200
# 2024-01-07 18:48:34.787010: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8600
# 2024-01-07 18:48:34.924463: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2024-01-07 18:48:34.925281: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x1f1ebab0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-01-07 18:48:34.925309: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA A100 80GB PCIe, Compute Capability 8.0
# 2024-01-07 18:48:34.933835: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-01-07 18:48:35.058220: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 1242/1244 [============================>.] - ETA: 0s - loss: 0.1163 - mae: 0.2395
# Epoch 1: val_loss improved from inf to 0.09698, saving model to ./Saved_Models_Data/P40_U32_OA/best_enc_dec_3.h5
# 1244/1244 [==============================] - 18s 12ms/step - loss: 0.1162 - mae: 0.2394 - val_loss: 0.0970 - val_mae: 0.2109
# Epoch 2/200
#   16/1244 [..............................] - ETA: 13s - loss: 0.0976 - mae: 0.2104
# /usr/local/lib/python3.8/dist-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 1242/1244 [============================>.] - ETA: 0s - loss: 0.0865 - mae: 0.1865
# Epoch 2: val_loss improved from 0.09698 to 0.07751, saving model to ./Saved_Models_Data/P40_U32_OA/best_enc_dec_3.h5
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0865 - mae: 0.1865 - val_loss: 0.0775 - val_mae: 0.1653
# Epoch 3/200
# 1241/1244 [============================>.] - ETA: 0s - loss: 0.0755 - mae: 0.1562
# Epoch 3: val_loss improved from 0.07751 to 0.07492, saving model to ./Saved_Models_Data/P40_U32_OA/best_enc_dec_3.h5
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0755 - mae: 0.1562 - val_loss: 0.0749 - val_mae: 0.1498
# Epoch 4/200
# 1241/1244 [============================>.] - ETA: 0s - loss: 0.0720 - mae: 0.1449
# Epoch 4: val_loss improved from 0.07492 to 0.07231, saving model to ./Saved_Models_Data/P40_U32_OA/best_enc_dec_3.h5
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0720 - mae: 0.1449 - val_loss: 0.0723 - val_mae: 0.1412
# Epoch 5/200
# 1244/1244 [==============================] - ETA: 0s - loss: 0.0697 - mae: 0.1385
# Epoch 5: val_loss improved from 0.07231 to 0.06775, saving model to ./Saved_Models_Data/P40_U32_OA/best_enc_dec_3.h5
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0697 - mae: 0.1385 - val_loss: 0.0678 - val_mae: 0.1355
# Epoch 6/200
# 1244/1244 [==============================] - ETA: 0s - loss: 0.0680 - mae: 0.1337
# Epoch 6: val_loss improved from 0.06775 to 0.06585, saving model to ./Saved_Models_Data/P40_U32_OA/best_enc_dec_3.h5
# 1244/1244 [==============================] - 14s 12ms/step - loss: 0.0680 - mae: 0.1337 - val_loss: 0.0659 - val_mae: 0.1297
# Epoch 7/200
# 1240/1244 [============================>.] - ETA: 0s - loss: 0.0661 - mae: 0.1288
# Epoch 7: val_loss did not improve from 0.06585
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0661 - mae: 0.1288 - val_loss: 0.0665 - val_mae: 0.1273
# Epoch 8/200
# 1241/1244 [============================>.] - ETA: 0s - loss: 0.0649 - mae: 0.1256
# Epoch 8: val_loss improved from 0.06585 to 0.06250, saving model to ./Saved_Models_Data/P40_U32_OA/best_enc_dec_3.h5
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0649 - mae: 0.1256 - val_loss: 0.0625 - val_mae: 0.1222
# Epoch 9/200
# 1243/1244 [============================>.] - ETA: 0s - loss: 0.0631 - mae: 0.1221
# Epoch 9: val_loss improved from 0.06250 to 0.06171, saving model to ./Saved_Models_Data/P40_U32_OA/best_enc_dec_3.h5
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0631 - mae: 0.1221 - val_loss: 0.0617 - val_mae: 0.1195
# Epoch 10/200
# 1243/1244 [============================>.] - ETA: 0s - loss: 0.0629 - mae: 0.1207
# Epoch 10: val_loss did not improve from 0.06171
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0629 - mae: 0.1207 - val_loss: 0.0885 - val_mae: 0.1438
# Epoch 11/200
# 1243/1244 [============================>.] - ETA: 0s - loss: 0.0619 - mae: 0.1186
# Epoch 11: val_loss improved from 0.06171 to 0.05950, saving model to ./Saved_Models_Data/P40_U32_OA/best_enc_dec_3.h5
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0619 - mae: 0.1186 - val_loss: 0.0595 - val_mae: 0.1150
# Epoch 12/200
# 1243/1244 [============================>.] - ETA: 0s - loss: 0.0621 - mae: 0.1185
# Epoch 12: val_loss improved from 0.05950 to 0.05908, saving model to ./Saved_Models_Data/P40_U32_OA/best_enc_dec_3.h5
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0621 - mae: 0.1185 - val_loss: 0.0591 - val_mae: 0.1150
# Epoch 13/200
# 1241/1244 [============================>.] - ETA: 0s - loss: 0.0609 - mae: 0.1166
# Epoch 13: val_loss did not improve from 0.05908
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0609 - mae: 0.1166 - val_loss: 0.0599 - val_mae: 0.1154
# Epoch 14/200
# 1241/1244 [============================>.] - ETA: 0s - loss: 0.0591 - mae: 0.1139
# Epoch 14: val_loss improved from 0.05908 to 0.05887, saving model to ./Saved_Models_Data/P40_U32_OA/best_enc_dec_3.h5
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0591 - mae: 0.1139 - val_loss: 0.0589 - val_mae: 0.1148
# Epoch 15/200
# 1239/1244 [============================>.] - ETA: 0s - loss: 0.0588 - mae: 0.1132
# Epoch 15: val_loss improved from 0.05887 to 0.05688, saving model to ./Saved_Models_Data/P40_U32_OA/best_enc_dec_3.h5
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0588 - mae: 0.1132 - val_loss: 0.0569 - val_mae: 0.1112
# Epoch 16/200
# 1242/1244 [============================>.] - ETA: 0s - loss: 0.0582 - mae: 0.1122
# Epoch 16: val_loss improved from 0.05688 to 0.05635, saving model to ./Saved_Models_Data/P40_U32_OA/best_enc_dec_3.h5
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0582 - mae: 0.1122 - val_loss: 0.0564 - val_mae: 0.1096
# Epoch 17/200
# 1242/1244 [============================>.] - ETA: 0s - loss: 0.0566 - mae: 0.1098
# Epoch 17: val_loss improved from 0.05635 to 0.05567, saving model to ./Saved_Models_Data/P40_U32_OA/best_enc_dec_3.h5
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0566 - mae: 0.1097 - val_loss: 0.0557 - val_mae: 0.1090
# Epoch 18/200
# 1243/1244 [============================>.] - ETA: 0s - loss: 0.0570 - mae: 0.1096
# Epoch 18: val_loss improved from 0.05567 to 0.05407, saving model to ./Saved_Models_Data/P40_U32_OA/best_enc_dec_3.h5
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0570 - mae: 0.1096 - val_loss: 0.0541 - val_mae: 0.1066
# Epoch 19/200
# 1240/1244 [============================>.] - ETA: 0s - loss: 0.0561 - mae: 0.1083
# Epoch 19: val_loss did not improve from 0.05407
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0561 - mae: 0.1083 - val_loss: 0.0545 - val_mae: 0.1060
# Epoch 20/200
# 1243/1244 [============================>.] - ETA: 0s - loss: 0.0551 - mae: 0.1067
# Epoch 20: val_loss did not improve from 0.05407
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0551 - mae: 0.1067 - val_loss: 0.1664 - val_mae: 0.2162
# Epoch 21/200
# 1242/1244 [============================>.] - ETA: 0s - loss: 0.0841 - mae: 0.1372
# Epoch 21: val_loss did not improve from 0.05407
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0841 - mae: 0.1372 - val_loss: 0.0701 - val_mae: 0.1298
# Epoch 22/200
# 1241/1244 [============================>.] - ETA: 0s - loss: 0.0687 - mae: 0.1240
# Epoch 22: val_loss did not improve from 0.05407
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0687 - mae: 0.1240 - val_loss: 0.0661 - val_mae: 0.1199
# Epoch 23/200
# 1241/1244 [============================>.] - ETA: 0s - loss: 0.0664 - mae: 0.1188
# Epoch 23: val_loss did not improve from 0.05407
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0664 - mae: 0.1188 - val_loss: 0.0647 - val_mae: 0.1160
# Epoch 24/200
# 1240/1244 [============================>.] - ETA: 0s - loss: 0.0972 - mae: 0.1387
# Epoch 24: val_loss did not improve from 0.05407
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0972 - mae: 0.1387 - val_loss: 0.0856 - val_mae: 0.1349
# Epoch 25/200
# 1243/1244 [============================>.] - ETA: 0s - loss: 0.0807 - mae: 0.1289
# Epoch 25: val_loss did not improve from 0.05407
# 1244/1244 [==============================] - 14s 12ms/step - loss: 0.0807 - mae: 0.1289 - val_loss: 0.0725 - val_mae: 0.1257
# Epoch 26/200
# 1241/1244 [============================>.] - ETA: 0s - loss: 0.0848 - mae: 0.1417
# Epoch 26: val_loss did not improve from 0.05407
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0848 - mae: 0.1417 - val_loss: 0.0622 - val_mae: 0.1267
# Epoch 27/200
# 1244/1244 [==============================] - ETA: 0s - loss: 0.0590 - mae: 0.1187
# Epoch 27: val_loss did not improve from 0.05407
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0590 - mae: 0.1187 - val_loss: 0.0558 - val_mae: 0.1125
# Epoch 28/200
# 1240/1244 [============================>.] - ETA: 0s - loss: 0.0560 - mae: 0.1106
# Epoch 28: val_loss improved from 0.05407 to 0.05385, saving model to ./Saved_Models_Data/P40_U32_OA/best_enc_dec_3.h5
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0560 - mae: 0.1106 - val_loss: 0.0539 - val_mae: 0.1077
# Epoch 29/200
# 1244/1244 [==============================] - ETA: 0s - loss: 0.0537 - mae: 0.1055
# Epoch 29: val_loss improved from 0.05385 to 0.05191, saving model to ./Saved_Models_Data/P40_U32_OA/best_enc_dec_3.h5
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0537 - mae: 0.1055 - val_loss: 0.0519 - val_mae: 0.1016
# Epoch 30/200
# 1241/1244 [============================>.] - ETA: 0s - loss: 0.0522 - mae: 0.1019
# Epoch 30: val_loss improved from 0.05191 to 0.05140, saving model to ./Saved_Models_Data/P40_U32_OA/best_enc_dec_3.h5
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0522 - mae: 0.1019 - val_loss: 0.0514 - val_mae: 0.1001
# Epoch 31/200
# 1242/1244 [============================>.] - ETA: 0s - loss: 0.0535 - mae: 0.1029
# Epoch 31: val_loss improved from 0.05140 to 0.04921, saving model to ./Saved_Models_Data/P40_U32_OA/best_enc_dec_3.h5
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0535 - mae: 0.1029 - val_loss: 0.0492 - val_mae: 0.0977
# Epoch 32/200
# 1242/1244 [============================>.] - ETA: 0s - loss: 0.0508 - mae: 0.0990
# Epoch 32: val_loss did not improve from 0.04921
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0508 - mae: 0.0990 - val_loss: 0.0498 - val_mae: 0.0987
# Epoch 33/200
# 1241/1244 [============================>.] - ETA: 0s - loss: 0.0491 - mae: 0.0961
# Epoch 33: val_loss did not improve from 0.04921
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0491 - mae: 0.0961 - val_loss: 0.0497 - val_mae: 0.0969
# Epoch 34/200
# 1242/1244 [============================>.] - ETA: 0s - loss: 0.0488 - mae: 0.0948
# Epoch 34: val_loss improved from 0.04921 to 0.04884, saving model to ./Saved_Models_Data/P40_U32_OA/best_enc_dec_3.h5
# 1244/1244 [==============================] - 14s 12ms/step - loss: 0.0488 - mae: 0.0948 - val_loss: 0.0488 - val_mae: 0.0949
# Epoch 35/200
# 1241/1244 [============================>.] - ETA: 0s - loss: 0.0477 - mae: 0.0927
# Epoch 35: val_loss improved from 0.04884 to 0.04702, saving model to ./Saved_Models_Data/P40_U32_OA/best_enc_dec_3.h5
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0477 - mae: 0.0927 - val_loss: 0.0470 - val_mae: 0.0919
# Epoch 36/200
# 1242/1244 [============================>.] - ETA: 0s - loss: 0.0470 - mae: 0.0912
# Epoch 36: val_loss improved from 0.04702 to 0.04659, saving model to ./Saved_Models_Data/P40_U32_OA/best_enc_dec_3.h5
# 1244/1244 [==============================] - 14s 12ms/step - loss: 0.0470 - mae: 0.0912 - val_loss: 0.0466 - val_mae: 0.0916
# Epoch 37/200
# 1243/1244 [============================>.] - ETA: 0s - loss: 0.0467 - mae: 0.0903
# Epoch 37: val_loss improved from 0.04659 to 0.04565, saving model to ./Saved_Models_Data/P40_U32_OA/best_enc_dec_3.h5
# 1244/1244 [==============================] - 14s 12ms/step - loss: 0.0467 - mae: 0.0903 - val_loss: 0.0456 - val_mae: 0.0904
# Epoch 38/200
# 1239/1244 [============================>.] - ETA: 0s - loss: 0.0485 - mae: 0.0930
# Epoch 38: val_loss did not improve from 0.04565
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0485 - mae: 0.0930 - val_loss: 0.0462 - val_mae: 0.0892
# Epoch 39/200
# 1240/1244 [============================>.] - ETA: 0s - loss: 0.0457 - mae: 0.0886
# Epoch 39: val_loss improved from 0.04565 to 0.04472, saving model to ./Saved_Models_Data/P40_U32_OA/best_enc_dec_3.h5
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0457 - mae: 0.0886 - val_loss: 0.0447 - val_mae: 0.0863
# Epoch 40/200
# 1240/1244 [============================>.] - ETA: 0s - loss: 0.0611 - mae: 0.1083
# Epoch 40: val_loss did not improve from 0.04472
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0611 - mae: 0.1083 - val_loss: 0.0512 - val_mae: 0.0998
# Epoch 41/200
# 1240/1244 [============================>.] - ETA: 0s - loss: 0.0470 - mae: 0.0918
# Epoch 41: val_loss did not improve from 0.04472
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0471 - mae: 0.0918 - val_loss: 0.0471 - val_mae: 0.0901
# Epoch 42/200
# 1243/1244 [============================>.] - ETA: 0s - loss: 0.0452 - mae: 0.0875
# Epoch 42: val_loss improved from 0.04472 to 0.04437, saving model to ./Saved_Models_Data/P40_U32_OA/best_enc_dec_3.h5
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0452 - mae: 0.0875 - val_loss: 0.0444 - val_mae: 0.0854
# Epoch 43/200
# 1241/1244 [============================>.] - ETA: 0s - loss: 0.0655 - mae: 0.1058
# Epoch 43: val_loss did not improve from 0.04437
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0655 - mae: 0.1058 - val_loss: 0.0838 - val_mae: 0.1320
# Epoch 44/200
# 1243/1244 [============================>.] - ETA: 0s - loss: 0.0758 - mae: 0.1293
# Epoch 44: val_loss did not improve from 0.04437
# 1244/1244 [==============================] - 14s 12ms/step - loss: 0.0758 - mae: 0.1293 - val_loss: 0.0696 - val_mae: 0.1280
# Epoch 45/200
# 1242/1244 [============================>.] - ETA: 0s - loss: 0.0657 - mae: 0.1231
# Epoch 45: val_loss did not improve from 0.04437
# 1244/1244 [==============================] - 14s 12ms/step - loss: 0.0657 - mae: 0.1231 - val_loss: 0.0627 - val_mae: 0.1174
# Epoch 46/200
# 1242/1244 [============================>.] - ETA: 0s - loss: 0.0608 - mae: 0.1146
# Epoch 46: val_loss did not improve from 0.04437
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0608 - mae: 0.1146 - val_loss: 0.0584 - val_mae: 0.1109
# Epoch 47/200
# 1241/1244 [============================>.] - ETA: 0s - loss: 0.0663 - mae: 0.1161
# Epoch 47: val_loss did not improve from 0.04437
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0664 - mae: 0.1161 - val_loss: 0.0824 - val_mae: 0.1285
# Epoch 48/200
# 1241/1244 [============================>.] - ETA: 0s - loss: 0.0680 - mae: 0.1160
# Epoch 48: val_loss did not improve from 0.04437
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0680 - mae: 0.1160 - val_loss: 0.0627 - val_mae: 0.1104
# Epoch 49/200
# 1239/1244 [============================>.] - ETA: 0s - loss: 0.0610 - mae: 0.1076
# Epoch 49: val_loss did not improve from 0.04437
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0610 - mae: 0.1076 - val_loss: 0.0601 - val_mae: 0.1110
# Epoch 50/200
# 1241/1244 [============================>.] - ETA: 0s - loss: 0.0562 - mae: 0.1048
# Epoch 50: val_loss did not improve from 0.04437
# 1244/1244 [==============================] - 14s 12ms/step - loss: 0.0562 - mae: 0.1048 - val_loss: 0.0527 - val_mae: 0.1019
# Epoch 51/200
# 1242/1244 [============================>.] - ETA: 0s - loss: 0.0586 - mae: 0.1083
# Epoch 51: val_loss did not improve from 0.04437
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0586 - mae: 0.1083 - val_loss: 0.0599 - val_mae: 0.1124
# Epoch 52/200
# 1239/1244 [============================>.] - ETA: 0s - loss: 0.0608 - mae: 0.1100
# Epoch 52: val_loss did not improve from 0.04437
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0608 - mae: 0.1099 - val_loss: 0.0591 - val_mae: 0.1100
# Epoch 53/200
# 1243/1244 [============================>.] - ETA: 0s - loss: 0.0676 - mae: 0.1262
# Epoch 53: val_loss did not improve from 0.04437
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0676 - mae: 0.1262 - val_loss: 0.0581 - val_mae: 0.1112
# Epoch 54/200
# 1242/1244 [============================>.] - ETA: 0s - loss: 0.0570 - mae: 0.1069
# Epoch 54: val_loss did not improve from 0.04437
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0570 - mae: 0.1069 - val_loss: 0.0554 - val_mae: 0.1041
# Epoch 55/200
# 1244/1244 [==============================] - ETA: 0s - loss: 0.0551 - mae: 0.1024
# Epoch 55: val_loss did not improve from 0.04437
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0551 - mae: 0.1024 - val_loss: 0.0535 - val_mae: 0.0994
# Epoch 56/200
# 1241/1244 [============================>.] - ETA: 0s - loss: 0.0534 - mae: 0.0988
# Epoch 56: val_loss did not improve from 0.04437
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0534 - mae: 0.0988 - val_loss: 0.0524 - val_mae: 0.0979
# Epoch 57/200
# 1241/1244 [============================>.] - ETA: 0s - loss: 0.0523 - mae: 0.0961
# Epoch 57: val_loss did not improve from 0.04437
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0523 - mae: 0.0962 - val_loss: 0.0587 - val_mae: 0.1060
# Epoch 58/200
# 1240/1244 [============================>.] - ETA: 0s - loss: 0.0518 - mae: 0.0952
# Epoch 58: val_loss did not improve from 0.04437
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0518 - mae: 0.0952 - val_loss: 0.0513 - val_mae: 0.0949
# Epoch 59/200
# 1239/1244 [============================>.] - ETA: 0s - loss: 0.0508 - mae: 0.0940
# Epoch 59: val_loss did not improve from 0.04437
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0508 - mae: 0.0940 - val_loss: 0.0488 - val_mae: 0.0926
# Epoch 60/200
# 1244/1244 [==============================] - ETA: 0s - loss: 0.0600 - mae: 0.1026
# Epoch 60: val_loss did not improve from 0.04437
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0600 - mae: 0.1026 - val_loss: 0.1116 - val_mae: 0.1507
# Epoch 61/200
# 1243/1244 [============================>.] - ETA: 0s - loss: 0.1069 - mae: 0.1480
# Epoch 61: val_loss did not improve from 0.04437
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.1069 - mae: 0.1480 - val_loss: 0.0980 - val_mae: 0.1425
# Epoch 62/200
# 1243/1244 [============================>.] - ETA: 0s - loss: 0.0911 - mae: 0.1372
# Epoch 62: val_loss did not improve from 0.04437
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0911 - mae: 0.1372 - val_loss: 0.0830 - val_mae: 0.1314
# Epoch 63/200
# 1241/1244 [============================>.] - ETA: 0s - loss: 0.0785 - mae: 0.1316
# Epoch 63: val_loss did not improve from 0.04437
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0785 - mae: 0.1316 - val_loss: 0.0763 - val_mae: 0.1281
# Epoch 64/200
# 1241/1244 [============================>.] - ETA: 0s - loss: 0.0796 - mae: 0.1314
# Epoch 64: val_loss did not improve from 0.04437
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0795 - mae: 0.1314 - val_loss: 0.0736 - val_mae: 0.1234
# Epoch 65/200
# 1244/1244 [==============================] - ETA: 0s - loss: 0.0721 - mae: 0.1219
# Epoch 65: val_loss did not improve from 0.04437
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0721 - mae: 0.1219 - val_loss: 0.0701 - val_mae: 0.1196
# Epoch 66/200
# 1243/1244 [============================>.] - ETA: 0s - loss: 0.0680 - mae: 0.1171
# Epoch 66: val_loss did not improve from 0.04437
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0680 - mae: 0.1171 - val_loss: 0.0581 - val_mae: 0.1097
# Epoch 67/200
# 1243/1244 [============================>.] - ETA: 0s - loss: 0.0580 - mae: 0.1066
# Epoch 67: val_loss did not improve from 0.04437
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0580 - mae: 0.1066 - val_loss: 0.0570 - val_mae: 0.1027
# Epoch 68/200
# 1241/1244 [============================>.] - ETA: 0s - loss: 0.0608 - mae: 0.1078
# Epoch 68: val_loss did not improve from 0.04437
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0608 - mae: 0.1078 - val_loss: 0.0555 - val_mae: 0.1025
# Epoch 69/200
# 1241/1244 [============================>.] - ETA: 0s - loss: 0.0559 - mae: 0.1028
# Epoch 69: val_loss did not improve from 0.04437
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0559 - mae: 0.1028 - val_loss: 0.0534 - val_mae: 0.0998
# Epoch 70/200
# 1241/1244 [============================>.] - ETA: 0s - loss: 0.0533 - mae: 0.0987
# Epoch 70: val_loss did not improve from 0.04437
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0533 - mae: 0.0987 - val_loss: 0.0519 - val_mae: 0.0970
# Epoch 71/200
# 1243/1244 [============================>.] - ETA: 0s - loss: 0.0541 - mae: 0.0987
# Epoch 71: val_loss did not improve from 0.04437
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0541 - mae: 0.0987 - val_loss: 0.0520 - val_mae: 0.0969
# Epoch 72/200
# 1243/1244 [============================>.] - ETA: 0s - loss: 0.0516 - mae: 0.0951
# Epoch 72: val_loss did not improve from 0.04437
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0516 - mae: 0.0951 - val_loss: 0.0505 - val_mae: 0.0933
# Epoch 73/200
# 1240/1244 [============================>.] - ETA: 0s - loss: 0.0507 - mae: 0.0925
# Epoch 73: val_loss did not improve from 0.04437
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0507 - mae: 0.0925 - val_loss: 0.0509 - val_mae: 0.0917
# Epoch 74/200
# 1242/1244 [============================>.] - ETA: 0s - loss: 0.1198 - mae: 0.1583
# Epoch 74: val_loss did not improve from 0.04437
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.1198 - mae: 0.1582 - val_loss: 0.1013 - val_mae: 0.1468
# Epoch 75/200
# 1240/1244 [============================>.] - ETA: 0s - loss: 0.1057 - mae: 0.1478
# Epoch 75: val_loss did not improve from 0.04437
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.1057 - mae: 0.1478 - val_loss: 0.1182 - val_mae: 0.1551
# Epoch 76/200
# 1242/1244 [============================>.] - ETA: 0s - loss: 0.1158 - mae: 0.1528
# Epoch 76: val_loss did not improve from 0.04437
# 1244/1244 [==============================] - 14s 12ms/step - loss: 0.1158 - mae: 0.1528 - val_loss: 0.1136 - val_mae: 0.1498
# Epoch 77/200
# 1240/1244 [============================>.] - ETA: 0s - loss: 0.1023 - mae: 0.1453
# Epoch 77: val_loss did not improve from 0.04437
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.1023 - mae: 0.1453 - val_loss: 0.0933 - val_mae: 0.1395
# Epoch 78/200
# 1242/1244 [============================>.] - ETA: 0s - loss: 0.0916 - mae: 0.1372
# Epoch 78: val_loss did not improve from 0.04437
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0916 - mae: 0.1372 - val_loss: 0.0897 - val_mae: 0.1337
# Epoch 79/200
# 1242/1244 [============================>.] - ETA: 0s - loss: 0.0993 - mae: 0.1458
# Epoch 79: val_loss did not improve from 0.04437
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0993 - mae: 0.1458 - val_loss: 0.1357 - val_mae: 0.1703
# Epoch 80/200
# 1243/1244 [============================>.] - ETA: 0s - loss: 0.1251 - mae: 0.1611
# Epoch 80: val_loss did not improve from 0.04437
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.1251 - mae: 0.1611 - val_loss: 0.1177 - val_mae: 0.1520
# Epoch 81/200
# 1243/1244 [============================>.] - ETA: 0s - loss: 0.1157 - mae: 0.1534
# Epoch 81: val_loss did not improve from 0.04437
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.1157 - mae: 0.1534 - val_loss: 0.1123 - val_mae: 0.1548
# Epoch 82/200
# 1241/1244 [============================>.] - ETA: 0s - loss: 0.1092 - mae: 0.1597
# Epoch 82: val_loss did not improve from 0.04437
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.1092 - mae: 0.1596 - val_loss: 0.0952 - val_mae: 0.1531
# Epoch 82: early stopping

# %%
import numpy as np
import json
import matplotlib.pyplot as plt

save_path = "./Saved_Models_Data/P40_U32_OA/"
f = open(save_path+"history_3.json")
history = json.load(f)

# %%
# summarize history for loss
mod_name = "P40_U32_OA"
plt.plot(history['loss'])
plt.plot(history['val_loss'])
plt.title('Encoder Decoder Sequence Model '+mod_name+' loss (run 3)')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
#Evaluate the saved best model:
from keras.models import load_model
saved_model = load_model(save_path+"best_enc_dec_3.h5")
best_eval = saved_model.evaluate(X_test_reshaped, Y_test_reshaped)

print("Mean Squared Error: ", best_eval[0])
print("Mean Absolute Error: ", best_eval[1])

#RMSE:
mse_value = best_eval[0]
rmse_value = np.sqrt(mse_value)
print("Root Mean Squared Error (RMSE): ", rmse_value)

# %%
#Save the predictions
predictions = saved_model.predict(X_test_reshaped)
original_shape_predictions = predictions.reshape(X_test.shape[0], Y_test.shape[1])
np.save(save_path+"predictions_3.npy",original_shape_predictions)

#Save the ground truth:
np.save(save_path+"ground-truth_3.npy", Y_test)

# %%
#print some samples
y_pred = np.load(save_path+"predictions_3.npy")
y_true = np.load(save_path +"ground-truth_3.npy")

print(y_pred.shape)
print(y_true.shape)
#Print some samples:
for sample in range(5):
    print(f"SAMPLE: {sample}")
    for i in range (81):
        print(f"Index {i} Ground truth: {y_true[sample][i]} Predicted: {y_pred[sample][i]}")

# %%
#Can convert to Benesh version for predictions using a threshold here (0.5)
print("Converting the predictions to benesh versions:")
benesh_arr = np.zeros_like(y_pred)

for sample in range(len(y_pred)):
  #print(f"SAMPLE: {sample}")
  for i in range (81):
    # can add more logic here to change the thresholds for specific indices.
    if y_pred[sample][i] >= 0.5:
      benesh_arr[sample][i] = 1
    elif y_pred[sample][i] < 0.5:
      benesh_arr[sample][i]= 0

print(benesh_arr[:2])
np.save(save_path+"y_pred_benesh_3.npy", benesh_arr)

# %%
#save the error array
y_pred = np.load(save_path+"predictions_3.npy")
y_true = np.load(save_path+"ground-truth_3.npy")

err_arr = np.zeros((12433,81))

for r in range(len(y_pred)):
    for c in range(81):
        err_arr[r][c] = abs(y_true[r][c]-y_pred[r][c])
        
np.save(save_path+"err_arr_3.npy",err_arr)

# %%
import seaborn as sns
err_arr = np.load(save_path+"err_arr_3.npy")
#fig, ax = plt.subplots(figsize=(18, 9))
plt.figure(figsize = (20,10))
sns.boxplot(err_arr, fliersize = 0.1 ,gap=0.05).set(title='Box Plot for Sequence Model EncDec '+mod_name+', showing error for each vector index (run 3)')
plt.show()

# %%
def mean_abs_perc_err(gt_arr, pred_arr, num_samples, vec_size):
    err_arr = np.zeros((num_samples,vec_size))
    print("Calculating MAPE")
    for r in range(len(pred_arr)):
        for c in range(vec_size):
          err_arr[r][c] = abs(gt_arr[r][c]-pred_arr[r][c]) # Calculation of the percentage error
    per_sample_mape_arr = np.sum(err_arr,axis=1)/vec_size
    print(per_sample_mape_arr.shape)
    print("MAPE for 10 samples...",per_sample_mape_arr[:10])
    overall_MAPE = sum(per_sample_mape_arr)/num_samples*100 # Multiply by 100 to get the percentage
    print("OVERALL MAPE: ", overall_MAPE)

n_samples = 12433
v_size = 81
y_pred = np.load(save_path+"predictions_3.npy")
y_true = np.load(save_path+"ground-truth_3.npy")
mean_abs_perc_err(y_true,y_pred,n_samples,v_size)

# %%
from sklearn.metrics import r2_score

# %%
y_pred = np.load(save_path+"predictions_3.npy")
y_true = np.load(save_path+"ground-truth_3.npy")

# %%
#Calculate R2 Score:
result_r2 = np.zeros(y_true.shape[0])

for i in range(y_true.shape[0]):
    # Calculate the R-squared value for each row
    r2 = r2_score(y_true[i, :], y_pred[i, :])
    result_r2[i] = r2

print("R-squared value for each row (sample):", result_r2)
# Calculate the overall R-squared value
overall_r2 = np.mean(result_r2)

# Print the overall R-squared value
print("Overall R-squared value:", overall_r2)

# %%
#Spearman Correlation:
result = np.zeros(y_true.shape[0])

for i in range(y_true.shape[0]):
    # Calculate the Spearman correlation for each row
    row_result = scipy.stats.spearmanr(y_true[i, :], y_pred[i, :])

    # Checking for zero standard deviation
    if np.isnan(row_result.correlation) or np.isnan(row_result.pvalue):
        # Handle the case where the result contains NaN
        result[i] = 0  # Set the correlation coefficient to 0
    else:
        result[i] = row_result.correlation

print("Spearman correlation coefficients for each row (sample):", result)
overall_spearman_corr = np.mean(result)

# Print the overall Spearman correlation coefficient
print("Overall Spearman correlation coefficient:", overall_spearman_corr)

# %%
#Pearson Correlation:
result_pearson = np.zeros(y_true.shape[0])

for i in range(y_true.shape[0]):
    # Calculate the Pearson correlation for each row
    corr_matrix = np.corrcoef(y_true[i, :], y_pred[i, :])
    result_pearson[i] = corr_matrix[0, 1]

# Calculate the overall Pearson correlation coefficient
overall_pearson_corr = np.mean(result_pearson)

print("Pearson correlation coefficients for each row:", result_pearson)
print(len(result_pearson))
# Print the overall Pearson correlation coefficient
print("Overall Pearson correlation coefficient:", overall_pearson_corr)

# %%
from sklearn.metrics import matthews_corrcoef #calculated using the converted 0.5 threshold benesh vector
y_pred = np.load(save_path + "y_pred_benesh_3.npy")
y_true = np.load(save_path + "ground-truth_3.npy")

result_mcc = np.zeros(y_true.shape[0])

for i in range(y_true.shape[0]):
    # Calculate the Matthews Correlation Coefficient for each row
    mcc = matthews_corrcoef(y_true[i, :], y_pred[i, :])
    result_mcc[i] = mcc

# Calculate the overall Matthews Correlation Coefficient
overall_mcc = np.mean(result_mcc)

# Print the overall Matthews Correlation Coefficient
print("Overall Matthews Correlation Coefficient:", overall_mcc)

# %%
#Save boxplot stats
import numpy as np
save_path = "./Saved_Models_Data/P40_U32_OA/"

np.set_printoptions(suppress=True) # Disable scientific notation
filename = "err_arr_3.npy"

err = np.load(save_path+filename)
print(len(err))

stats = np.empty(shape = (0,5))
n_indices = len(err[0]) # should be 81
print(n_indices)

for i in range(n_indices):
    i_stats = np.percentile(err[:, i], [0, 25, 50, 75, 100]) # = [Min, Q1, Med, Q3, Max]
    stats = np.vstack([stats, i_stats]) # Add row to numpy stats object 
    print("index: {}".format(i), i_stats)

# print(stats)
out_filename = "boxplot_stats_3.csv"

np.savetxt(save_path+out_filename, stats, delimiter = ',', fmt='%f')
