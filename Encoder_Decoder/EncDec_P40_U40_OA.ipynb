# %%
import os

# Set the CUDA_VISIBLE_DEVICES environment variable
os.environ["CUDA_VISIBLE_DEVICES"] = "1"  # Replace with the GPU index you want to use

# Confirm the selected GPU
print(f"Using GPU {os.environ['CUDA_VISIBLE_DEVICES']} for the experiment.")
# Out:
# Using GPU 1 for the experiment.

# %%
#imports
import matplotlib.pyplot as plt
import h5py
import numpy as np
import scipy
import seaborn as sns
import math
import json
import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras.layers import Input, LSTM, RepeatVector, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.model_selection import train_test_split
# Out:
# 2024-01-07 18:45:21.404476: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    # Print the list of available GPUs
    for gpu in gpus:
        print("GPU:", gpu)
else:
    print("No GPU available.")
# Out:
# GPU: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')

# %%
#Prepare Training Data:
path_to_X = "../Normalised/X.npy"
path_to_Y = "../Normalised/Y.npy"
X = np.load(path_to_X)
Y = np.load(path_to_Y)
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state=42)
print(len(X_train))
print(len(X_test))
# Reshape the input and output data for the encoder and decoder
X_train_reshaped = X_train.reshape(X_train.shape[0], X_train.shape[1], 1) # (No of Data, 50) to (No of data, 50,1)
print("X_train_reshaped shape: ", X_train_reshaped.shape)
Y_train_reshaped = Y_train.reshape(Y_train.shape[0], Y_train.shape[1], 1)
print("Y_train_resahped shape: ", Y_train_reshaped.shape)
# Define the input shape for the encoder
input_shape = X_train_reshaped.shape[1:]  # Shape: (sequence_length, 1) # 50,1
print("Input_shape: ", input_shape)
X_test_reshaped = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
Y_test_reshaped = Y_test.reshape(Y_test.shape[0], Y_test.shape[1], 1)
print("X_test_reshaped",X_test_reshaped.shape)
print("Y_test_reshaped",Y_test_reshaped.shape)
# Out:
# 49730
# 12433
# X_train_reshaped shape:  (49730, 50, 1)
# Y_train_resahped shape:  (49730, 81, 1)
# Input_shape:  (50, 1)
# X_test_reshaped (12433, 50, 1)
# Y_test_reshaped (12433, 81, 1)

# %%
# Define the model
def createModel(units, optimizer):        
    # Define the encoder
    encoder_inputs = Input(shape=input_shape)
    encoder_lstm = LSTM(units)(encoder_inputs)
    encoder_model = Model(encoder_inputs, encoder_lstm)
    
    # Define the input shape for the decoder (with 40 units to match encoder LSTM units)
    decoder_inputs = Input(shape=(units,))  # This will serve as the initial state of the decoder LSTM
    decoder_lstm = LSTM(units, return_sequences=True)(RepeatVector(Y_train_reshaped.shape[1])(decoder_inputs))
    decoder_outputs = Dense(1, activation='sigmoid')(decoder_lstm)
    
    # Define the decoder model
    decoder_model = Model(decoder_inputs, decoder_outputs)
    
    # Create the full seq_model model
    seq_model_outputs = decoder_model(encoder_lstm)
    seq_model = Model(encoder_inputs, seq_model_outputs)
    
    # Compile the model
    seq_model.compile(optimizer=optimizer, loss='mean_squared_error', metrics = ['mae'])
    
    # Display the model summary
    seq_model.summary()
    return seq_model

# %%
#Train the model
tf.debugging.set_log_device_placement(False)

# Verify the available GPUs
gpus = tf.config.experimental.list_physical_devices('GPU')
print("GPUs:", gpus)
if gpus:
    # Use the first GPU for training
    with tf.device('/GPU:1'):
        seq_model = createModel(40,'adam')
        save_path = "./Saved_Models_Data/P40_U40_OA/"
        early_stopping = EarlyStopping(monitor='val_loss', patience=40, verbose=1)
        mc = ModelCheckpoint(save_path+"best_enc_dec_3.h5", monitor = 'val_loss',mode='min', save_best_only=True, verbose=1)
        history = seq_model.fit(X_train_reshaped, Y_train_reshaped, batch_size=32, epochs=200, validation_split=0.2, callbacks=[early_stopping, mc])
        with open(save_path+'history_3.json','w') as file:
            json.dump(history.history, file)
# Out:
# GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# 2024-01-07 18:46:12.766424: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 78946 MB memory:  -> device: 0, name: NVIDIA A100 80GB PCIe, pci bus id: 0000:25:00.0, compute capability: 8.0
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 50, 1)]           0
#
#  lstm (LSTM)                 (None, 40)                6720
#
#  model_1 (Functional)        (None, 81, 1)             13001
#
# =================================================================
# Total params: 19721 (77.04 KB)
# Trainable params: 19721 (77.04 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/200
# 2024-01-07 18:46:17.009387: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8600
# 2024-01-07 18:46:17.147015: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2024-01-07 18:46:17.147749: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x1d1b2b00 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-01-07 18:46:17.147784: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA A100 80GB PCIe, Compute Capability 8.0
# 2024-01-07 18:46:17.155460: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-01-07 18:46:17.275509: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 1240/1244 [============================>.] - ETA: 0s - loss: 0.1092 - mae: 0.2244
# Epoch 1: val_loss improved from inf to 0.08068, saving model to ./Saved_Models_Data/P40_U40_OA/best_enc_dec_3.h5
# 1244/1244 [==============================] - 17s 11ms/step - loss: 0.1092 - mae: 0.2243 - val_loss: 0.0807 - val_mae: 0.1582
# Epoch 2/200
#   11/1244 [..............................] - ETA: 13s - loss: 0.0820 - mae: 0.1601
# /usr/local/lib/python3.8/dist-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 1243/1244 [============================>.] - ETA: 0s - loss: 0.0921 - mae: 0.1740
# Epoch 2: val_loss did not improve from 0.08068
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0921 - mae: 0.1740 - val_loss: 0.0822 - val_mae: 0.1592
# Epoch 3/200
# 1241/1244 [============================>.] - ETA: 0s - loss: 0.1075 - mae: 0.2099
# Epoch 3: val_loss did not improve from 0.08068
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.1075 - mae: 0.2099 - val_loss: 0.0919 - val_mae: 0.2003
# Epoch 4/200
# 1244/1244 [==============================] - ETA: 0s - loss: 0.0878 - mae: 0.1731
# Epoch 4: val_loss did not improve from 0.08068
# 1244/1244 [==============================] - 14s 12ms/step - loss: 0.0878 - mae: 0.1731 - val_loss: 0.0859 - val_mae: 0.1666
# Epoch 5/200
# 1241/1244 [============================>.] - ETA: 0s - loss: 0.0802 - mae: 0.1574
# Epoch 5: val_loss improved from 0.08068 to 0.07729, saving model to ./Saved_Models_Data/P40_U40_OA/best_enc_dec_3.h5
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0802 - mae: 0.1573 - val_loss: 0.0773 - val_mae: 0.1487
# Epoch 6/200
# 1243/1244 [============================>.] - ETA: 0s - loss: 0.0784 - mae: 0.1506
# Epoch 6: val_loss improved from 0.07729 to 0.07639, saving model to ./Saved_Models_Data/P40_U40_OA/best_enc_dec_3.h5
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0784 - mae: 0.1506 - val_loss: 0.0764 - val_mae: 0.1480
# Epoch 7/200
# 1241/1244 [============================>.] - ETA: 0s - loss: 0.0755 - mae: 0.1441
# Epoch 7: val_loss improved from 0.07639 to 0.07615, saving model to ./Saved_Models_Data/P40_U40_OA/best_enc_dec_3.h5
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0754 - mae: 0.1441 - val_loss: 0.0761 - val_mae: 0.1459
# Epoch 8/200
# 1239/1244 [============================>.] - ETA: 0s - loss: 0.0797 - mae: 0.1426
# Epoch 8: val_loss did not improve from 0.07615
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0797 - mae: 0.1427 - val_loss: 0.0847 - val_mae: 0.1705
# Epoch 9/200
# 1241/1244 [============================>.] - ETA: 0s - loss: 0.0750 - mae: 0.1406
# Epoch 9: val_loss improved from 0.07615 to 0.07099, saving model to ./Saved_Models_Data/P40_U40_OA/best_enc_dec_3.h5
# 1244/1244 [==============================] - 21s 17ms/step - loss: 0.0750 - mae: 0.1405 - val_loss: 0.0710 - val_mae: 0.1321
# Epoch 10/200
# 1242/1244 [============================>.] - ETA: 0s - loss: 0.0696 - mae: 0.1275
# Epoch 10: val_loss improved from 0.07099 to 0.06730, saving model to ./Saved_Models_Data/P40_U40_OA/best_enc_dec_3.h5
# 1244/1244 [==============================] - 13s 11ms/step - loss: 0.0695 - mae: 0.1275 - val_loss: 0.0673 - val_mae: 0.1239
# Epoch 11/200
# 1243/1244 [============================>.] - ETA: 0s - loss: 0.0670 - mae: 0.1226
# Epoch 11: val_loss improved from 0.06730 to 0.06651, saving model to ./Saved_Models_Data/P40_U40_OA/best_enc_dec_3.h5
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0670 - mae: 0.1226 - val_loss: 0.0665 - val_mae: 0.1212
# Epoch 12/200
# 1240/1244 [============================>.] - ETA: 0s - loss: 0.0654 - mae: 0.1198
# Epoch 12: val_loss improved from 0.06651 to 0.06590, saving model to ./Saved_Models_Data/P40_U40_OA/best_enc_dec_3.h5
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0654 - mae: 0.1198 - val_loss: 0.0659 - val_mae: 0.1183
# Epoch 13/200
# 1242/1244 [============================>.] - ETA: 0s - loss: 0.0646 - mae: 0.1180
# Epoch 13: val_loss improved from 0.06590 to 0.06391, saving model to ./Saved_Models_Data/P40_U40_OA/best_enc_dec_3.h5
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0646 - mae: 0.1180 - val_loss: 0.0639 - val_mae: 0.1167
# Epoch 14/200
# 1244/1244 [==============================] - ETA: 0s - loss: 0.0634 - mae: 0.1159
# Epoch 14: val_loss improved from 0.06391 to 0.06155, saving model to ./Saved_Models_Data/P40_U40_OA/best_enc_dec_3.h5
# 1244/1244 [==============================] - 15s 12ms/step - loss: 0.0634 - mae: 0.1159 - val_loss: 0.0616 - val_mae: 0.1114
# Epoch 15/200
# 1244/1244 [==============================] - ETA: 0s - loss: 0.0622 - mae: 0.1135
# Epoch 15: val_loss improved from 0.06155 to 0.06142, saving model to ./Saved_Models_Data/P40_U40_OA/best_enc_dec_3.h5
# 1244/1244 [==============================] - 14s 12ms/step - loss: 0.0622 - mae: 0.1135 - val_loss: 0.0614 - val_mae: 0.1128
# Epoch 16/200
# 1241/1244 [============================>.] - ETA: 0s - loss: 0.0610 - mae: 0.1109
# Epoch 16: val_loss improved from 0.06142 to 0.06124, saving model to ./Saved_Models_Data/P40_U40_OA/best_enc_dec_3.h5
# 1244/1244 [==============================] - 14s 12ms/step - loss: 0.0610 - mae: 0.1109 - val_loss: 0.0612 - val_mae: 0.1111
# Epoch 17/200
# 1244/1244 [==============================] - ETA: 0s - loss: 0.0971 - mae: 0.1719
# Epoch 17: val_loss did not improve from 0.06124
# 1244/1244 [==============================] - 14s 12ms/step - loss: 0.0971 - mae: 0.1719 - val_loss: 0.0866 - val_mae: 0.1442
# Epoch 18/200
# 1243/1244 [============================>.] - ETA: 0s - loss: 0.0836 - mae: 0.1376
# Epoch 18: val_loss did not improve from 0.06124
# 1244/1244 [==============================] - 14s 12ms/step - loss: 0.0836 - mae: 0.1376 - val_loss: 0.0806 - val_mae: 0.1350
# Epoch 19/200
# 1242/1244 [============================>.] - ETA: 0s - loss: 0.0793 - mae: 0.1327
# Epoch 19: val_loss did not improve from 0.06124
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0793 - mae: 0.1327 - val_loss: 0.0746 - val_mae: 0.1352
# Epoch 20/200
# 1241/1244 [============================>.] - ETA: 0s - loss: 0.0718 - mae: 0.1279
# Epoch 20: val_loss did not improve from 0.06124
# 1244/1244 [==============================] - 14s 12ms/step - loss: 0.0718 - mae: 0.1279 - val_loss: 0.0701 - val_mae: 0.1266
# Epoch 21/200
# 1241/1244 [============================>.] - ETA: 0s - loss: 0.0682 - mae: 0.1234
# Epoch 21: val_loss did not improve from 0.06124
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0682 - mae: 0.1234 - val_loss: 0.0666 - val_mae: 0.1188
# Epoch 22/200
# 1244/1244 [==============================] - ETA: 0s - loss: 0.0660 - mae: 0.1200
# Epoch 22: val_loss did not improve from 0.06124
# 1244/1244 [==============================] - 15s 12ms/step - loss: 0.0660 - mae: 0.1200 - val_loss: 0.0670 - val_mae: 0.1222
# Epoch 23/200
# 1244/1244 [==============================] - ETA: 0s - loss: 0.0613 - mae: 0.1209
# Epoch 23: val_loss improved from 0.06124 to 0.06099, saving model to ./Saved_Models_Data/P40_U40_OA/best_enc_dec_3.h5
# 1244/1244 [==============================] - 14s 12ms/step - loss: 0.0613 - mae: 0.1209 - val_loss: 0.0610 - val_mae: 0.1188
# Epoch 24/200
# 1244/1244 [==============================] - ETA: 0s - loss: 0.0596 - mae: 0.1176
# Epoch 24: val_loss improved from 0.06099 to 0.05928, saving model to ./Saved_Models_Data/P40_U40_OA/best_enc_dec_3.h5
# 1244/1244 [==============================] - 15s 12ms/step - loss: 0.0596 - mae: 0.1176 - val_loss: 0.0593 - val_mae: 0.1152
# Epoch 25/200
# 1244/1244 [==============================] - ETA: 0s - loss: 0.0566 - mae: 0.1117
# Epoch 25: val_loss improved from 0.05928 to 0.05545, saving model to ./Saved_Models_Data/P40_U40_OA/best_enc_dec_3.h5
# 1244/1244 [==============================] - 14s 12ms/step - loss: 0.0566 - mae: 0.1117 - val_loss: 0.0555 - val_mae: 0.1098
# Epoch 26/200
# 1242/1244 [============================>.] - ETA: 0s - loss: 0.0692 - mae: 0.1256
# Epoch 26: val_loss did not improve from 0.05545
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0692 - mae: 0.1256 - val_loss: 0.0621 - val_mae: 0.1166
# Epoch 27/200
# 1239/1244 [============================>.] - ETA: 0s - loss: 0.0584 - mae: 0.1131
# Epoch 27: val_loss improved from 0.05545 to 0.05432, saving model to ./Saved_Models_Data/P40_U40_OA/best_enc_dec_3.h5
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0584 - mae: 0.1131 - val_loss: 0.0543 - val_mae: 0.1078
# Epoch 28/200
# 1241/1244 [============================>.] - ETA: 0s - loss: 0.0538 - mae: 0.1063
# Epoch 28: val_loss improved from 0.05432 to 0.05303, saving model to ./Saved_Models_Data/P40_U40_OA/best_enc_dec_3.h5
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0538 - mae: 0.1063 - val_loss: 0.0530 - val_mae: 0.1053
# Epoch 29/200
# 1241/1244 [============================>.] - ETA: 0s - loss: 0.0512 - mae: 0.1026
# Epoch 29: val_loss improved from 0.05303 to 0.04989, saving model to ./Saved_Models_Data/P40_U40_OA/best_enc_dec_3.h5
# 1244/1244 [==============================] - 14s 12ms/step - loss: 0.0513 - mae: 0.1027 - val_loss: 0.0499 - val_mae: 0.1002
# Epoch 30/200
# 1240/1244 [============================>.] - ETA: 0s - loss: 0.0498 - mae: 0.1001
# Epoch 30: val_loss did not improve from 0.04989
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0498 - mae: 0.1001 - val_loss: 0.0502 - val_mae: 0.1009
# Epoch 31/200
# 1241/1244 [============================>.] - ETA: 0s - loss: 0.0484 - mae: 0.0969
# Epoch 31: val_loss improved from 0.04989 to 0.04938, saving model to ./Saved_Models_Data/P40_U40_OA/best_enc_dec_3.h5
# 1244/1244 [==============================] - 14s 12ms/step - loss: 0.0484 - mae: 0.0969 - val_loss: 0.0494 - val_mae: 0.0956
# Epoch 32/200
# 1240/1244 [============================>.] - ETA: 0s - loss: 0.0464 - mae: 0.0932
# Epoch 32: val_loss improved from 0.04938 to 0.04503, saving model to ./Saved_Models_Data/P40_U40_OA/best_enc_dec_3.h5
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0464 - mae: 0.0931 - val_loss: 0.0450 - val_mae: 0.0899
# Epoch 33/200
# 1244/1244 [==============================] - ETA: 0s - loss: 0.0469 - mae: 0.0934
# Epoch 33: val_loss improved from 0.04503 to 0.04376, saving model to ./Saved_Models_Data/P40_U40_OA/best_enc_dec_3.h5
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0469 - mae: 0.0934 - val_loss: 0.0438 - val_mae: 0.0881
# Epoch 34/200
# 1241/1244 [============================>.] - ETA: 0s - loss: 0.0441 - mae: 0.0880
# Epoch 34: val_loss improved from 0.04376 to 0.04308, saving model to ./Saved_Models_Data/P40_U40_OA/best_enc_dec_3.h5
# 1244/1244 [==============================] - 14s 12ms/step - loss: 0.0440 - mae: 0.0880 - val_loss: 0.0431 - val_mae: 0.0857
# Epoch 35/200
# 1239/1244 [============================>.] - ETA: 0s - loss: 0.0722 - mae: 0.1284
# Epoch 35: val_loss did not improve from 0.04308
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0722 - mae: 0.1284 - val_loss: 0.0642 - val_mae: 0.1270
# Epoch 36/200
# 1244/1244 [==============================] - ETA: 0s - loss: 0.0604 - mae: 0.1205
# Epoch 36: val_loss did not improve from 0.04308
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0604 - mae: 0.1205 - val_loss: 0.0601 - val_mae: 0.1149
# Epoch 37/200
# 1240/1244 [============================>.] - ETA: 0s - loss: 0.0539 - mae: 0.1088
# Epoch 37: val_loss did not improve from 0.04308
# 1244/1244 [==============================] - 14s 12ms/step - loss: 0.0538 - mae: 0.1088 - val_loss: 0.0519 - val_mae: 0.1049
# Epoch 38/200
# 1240/1244 [============================>.] - ETA: 0s - loss: 0.0491 - mae: 0.1003
# Epoch 38: val_loss did not improve from 0.04308
# 1244/1244 [==============================] - 14s 12ms/step - loss: 0.0491 - mae: 0.1003 - val_loss: 0.0471 - val_mae: 0.0966
# Epoch 39/200
# 1242/1244 [============================>.] - ETA: 0s - loss: 0.0462 - mae: 0.0942
# Epoch 39: val_loss did not improve from 0.04308
# 1244/1244 [==============================] - 14s 12ms/step - loss: 0.0462 - mae: 0.0942 - val_loss: 0.0444 - val_mae: 0.0907
# Epoch 40/200
# 1240/1244 [============================>.] - ETA: 0s - loss: 0.0446 - mae: 0.0905
# Epoch 40: val_loss did not improve from 0.04308
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0446 - mae: 0.0905 - val_loss: 0.0441 - val_mae: 0.0885
# Epoch 41/200
# 1243/1244 [============================>.] - ETA: 0s - loss: 0.0432 - mae: 0.0881
# Epoch 41: val_loss improved from 0.04308 to 0.04264, saving model to ./Saved_Models_Data/P40_U40_OA/best_enc_dec_3.h5
# 1244/1244 [==============================] - 14s 12ms/step - loss: 0.0432 - mae: 0.0881 - val_loss: 0.0426 - val_mae: 0.0867
# Epoch 42/200
# 1244/1244 [==============================] - ETA: 0s - loss: 0.0419 - mae: 0.0853
# Epoch 42: val_loss improved from 0.04264 to 0.04151, saving model to ./Saved_Models_Data/P40_U40_OA/best_enc_dec_3.h5
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0419 - mae: 0.0853 - val_loss: 0.0415 - val_mae: 0.0834
# Epoch 43/200
# 1240/1244 [============================>.] - ETA: 0s - loss: 0.0439 - mae: 0.0866
# Epoch 43: val_loss improved from 0.04151 to 0.04056, saving model to ./Saved_Models_Data/P40_U40_OA/best_enc_dec_3.h5
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0439 - mae: 0.0866 - val_loss: 0.0406 - val_mae: 0.0828
# Epoch 44/200
# 1241/1244 [============================>.] - ETA: 0s - loss: 0.0400 - mae: 0.0811
# Epoch 44: val_loss improved from 0.04056 to 0.03831, saving model to ./Saved_Models_Data/P40_U40_OA/best_enc_dec_3.h5
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0400 - mae: 0.0812 - val_loss: 0.0383 - val_mae: 0.0797
# Epoch 45/200
# 1242/1244 [============================>.] - ETA: 0s - loss: 0.0390 - mae: 0.0787
# Epoch 45: val_loss did not improve from 0.03831
# 1244/1244 [==============================] - 14s 12ms/step - loss: 0.0390 - mae: 0.0787 - val_loss: 0.0393 - val_mae: 0.0790
# Epoch 46/200
# 1243/1244 [============================>.] - ETA: 0s - loss: 0.0580 - mae: 0.1010
# Epoch 46: val_loss did not improve from 0.03831
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0580 - mae: 0.1010 - val_loss: 0.0728 - val_mae: 0.1337
# Epoch 47/200
# 1240/1244 [============================>.] - ETA: 0s - loss: 0.0631 - mae: 0.1185
# Epoch 47: val_loss did not improve from 0.03831
# 1244/1244 [==============================] - 14s 12ms/step - loss: 0.0631 - mae: 0.1184 - val_loss: 0.0559 - val_mae: 0.1063
# Epoch 48/200
# 1239/1244 [============================>.] - ETA: 0s - loss: 0.0542 - mae: 0.1000
# Epoch 48: val_loss did not improve from 0.03831
# 1244/1244 [==============================] - 14s 12ms/step - loss: 0.0542 - mae: 0.0999 - val_loss: 0.0519 - val_mae: 0.0941
# Epoch 49/200
# 1243/1244 [============================>.] - ETA: 0s - loss: 0.0499 - mae: 0.0913
# Epoch 49: val_loss did not improve from 0.03831
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0499 - mae: 0.0913 - val_loss: 0.0480 - val_mae: 0.0866
# Epoch 50/200
# 1243/1244 [============================>.] - ETA: 0s - loss: 0.0476 - mae: 0.0858
# Epoch 50: val_loss did not improve from 0.03831
# 1244/1244 [==============================] - 14s 12ms/step - loss: 0.0476 - mae: 0.0858 - val_loss: 0.0471 - val_mae: 0.0847
# Epoch 51/200
# 1243/1244 [============================>.] - ETA: 0s - loss: 0.0460 - mae: 0.0820
# Epoch 51: val_loss did not improve from 0.03831
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0460 - mae: 0.0820 - val_loss: 0.0444 - val_mae: 0.0794
# Epoch 52/200
# 1241/1244 [============================>.] - ETA: 0s - loss: 0.0449 - mae: 0.0803
# Epoch 52: val_loss did not improve from 0.03831
# 1244/1244 [==============================] - 14s 12ms/step - loss: 0.0449 - mae: 0.0803 - val_loss: 0.0431 - val_mae: 0.0791
# Epoch 53/200
# 1241/1244 [============================>.] - ETA: 0s - loss: 0.0425 - mae: 0.0778
# Epoch 53: val_loss did not improve from 0.03831
# 1244/1244 [==============================] - 15s 12ms/step - loss: 0.0425 - mae: 0.0778 - val_loss: 0.0416 - val_mae: 0.0756
# Epoch 54/200
# 1243/1244 [============================>.] - ETA: 0s - loss: 0.0414 - mae: 0.0753
# Epoch 54: val_loss did not improve from 0.03831
# 1244/1244 [==============================] - 14s 12ms/step - loss: 0.0414 - mae: 0.0753 - val_loss: 0.0417 - val_mae: 0.0750
# Epoch 55/200
# 1240/1244 [============================>.] - ETA: 0s - loss: 0.0409 - mae: 0.0740
# Epoch 55: val_loss did not improve from 0.03831
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0409 - mae: 0.0740 - val_loss: 0.0398 - val_mae: 0.0715
# Epoch 56/200
# 1240/1244 [============================>.] - ETA: 0s - loss: 0.0403 - mae: 0.0725
# Epoch 56: val_loss did not improve from 0.03831
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0402 - mae: 0.0725 - val_loss: 0.0400 - val_mae: 0.0717
# Epoch 57/200
# 1241/1244 [============================>.] - ETA: 0s - loss: 0.0394 - mae: 0.0710
# Epoch 57: val_loss did not improve from 0.03831
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0394 - mae: 0.0710 - val_loss: 0.0393 - val_mae: 0.0704
# Epoch 58/200
# 1243/1244 [============================>.] - ETA: 0s - loss: 0.0395 - mae: 0.0708
# Epoch 58: val_loss did not improve from 0.03831
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0395 - mae: 0.0708 - val_loss: 0.0387 - val_mae: 0.0690
# Epoch 59/200
# 1242/1244 [============================>.] - ETA: 0s - loss: 0.0631 - mae: 0.0908
# Epoch 59: val_loss did not improve from 0.03831
# 1244/1244 [==============================] - 15s 12ms/step - loss: 0.0631 - mae: 0.0908 - val_loss: 0.1174 - val_mae: 0.1443
# Epoch 60/200
# 1242/1244 [============================>.] - ETA: 0s - loss: 0.0762 - mae: 0.1239
# Epoch 60: val_loss did not improve from 0.03831
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0762 - mae: 0.1239 - val_loss: 0.0679 - val_mae: 0.1164
# Epoch 61/200
# 1241/1244 [============================>.] - ETA: 0s - loss: 0.0619 - mae: 0.1111
# Epoch 61: val_loss did not improve from 0.03831
# 1244/1244 [==============================] - 14s 12ms/step - loss: 0.0619 - mae: 0.1111 - val_loss: 0.0571 - val_mae: 0.1034
# Epoch 62/200
# 1240/1244 [============================>.] - ETA: 0s - loss: 0.0550 - mae: 0.0999
# Epoch 62: val_loss did not improve from 0.03831
# 1244/1244 [==============================] - 14s 12ms/step - loss: 0.0550 - mae: 0.0999 - val_loss: 0.0516 - val_mae: 0.0944
# Epoch 63/200
# 1241/1244 [============================>.] - ETA: 0s - loss: 0.0491 - mae: 0.0922
# Epoch 63: val_loss did not improve from 0.03831
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0491 - mae: 0.0922 - val_loss: 0.0474 - val_mae: 0.0868
# Epoch 64/200
# 1243/1244 [============================>.] - ETA: 0s - loss: 0.0458 - mae: 0.0861
# Epoch 64: val_loss did not improve from 0.03831
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0458 - mae: 0.0861 - val_loss: 0.0441 - val_mae: 0.0826
# Epoch 65/200
# 1241/1244 [============================>.] - ETA: 0s - loss: 0.0448 - mae: 0.0833
# Epoch 65: val_loss did not improve from 0.03831
# 1244/1244 [==============================] - 14s 12ms/step - loss: 0.0448 - mae: 0.0833 - val_loss: 0.0433 - val_mae: 0.0804
# Epoch 66/200
# 1243/1244 [============================>.] - ETA: 0s - loss: 0.0428 - mae: 0.0796
# Epoch 66: val_loss did not improve from 0.03831
# 1244/1244 [==============================] - 14s 12ms/step - loss: 0.0428 - mae: 0.0796 - val_loss: 0.0411 - val_mae: 0.0760
# Epoch 67/200
# 1239/1244 [============================>.] - ETA: 0s - loss: 0.0415 - mae: 0.0767
# Epoch 67: val_loss did not improve from 0.03831
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0415 - mae: 0.0767 - val_loss: 0.0420 - val_mae: 0.0755
# Epoch 68/200
# 1239/1244 [============================>.] - ETA: 0s - loss: 0.0432 - mae: 0.0792
# Epoch 68: val_loss did not improve from 0.03831
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0432 - mae: 0.0792 - val_loss: 0.0398 - val_mae: 0.0743
# Epoch 69/200
# 1244/1244 [==============================] - ETA: 0s - loss: 0.0402 - mae: 0.0743
# Epoch 69: val_loss did not improve from 0.03831
# 1244/1244 [==============================] - 14s 12ms/step - loss: 0.0402 - mae: 0.0743 - val_loss: 0.0394 - val_mae: 0.0722
# Epoch 70/200
# 1242/1244 [============================>.] - ETA: 0s - loss: 0.0391 - mae: 0.0718
# Epoch 70: val_loss did not improve from 0.03831
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0391 - mae: 0.0718 - val_loss: 0.0395 - val_mae: 0.0720
# Epoch 71/200
# 1240/1244 [============================>.] - ETA: 0s - loss: 0.0393 - mae: 0.0715
# Epoch 71: val_loss improved from 0.03831 to 0.03803, saving model to ./Saved_Models_Data/P40_U40_OA/best_enc_dec_3.h5
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0393 - mae: 0.0715 - val_loss: 0.0380 - val_mae: 0.0695
# Epoch 72/200
# 1244/1244 [==============================] - ETA: 0s - loss: 0.0381 - mae: 0.0693
# Epoch 72: val_loss improved from 0.03803 to 0.03725, saving model to ./Saved_Models_Data/P40_U40_OA/best_enc_dec_3.h5
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0381 - mae: 0.0693 - val_loss: 0.0373 - val_mae: 0.0673
# Epoch 73/200
# 1242/1244 [============================>.] - ETA: 0s - loss: 0.0379 - mae: 0.0685
# Epoch 73: val_loss did not improve from 0.03725
# 1244/1244 [==============================] - 14s 12ms/step - loss: 0.0379 - mae: 0.0685 - val_loss: 0.0373 - val_mae: 0.0688
# Epoch 74/200
# 1240/1244 [============================>.] - ETA: 0s - loss: 0.0388 - mae: 0.0701
# Epoch 74: val_loss improved from 0.03725 to 0.03674, saving model to ./Saved_Models_Data/P40_U40_OA/best_enc_dec_3.h5
# 1244/1244 [==============================] - 14s 12ms/step - loss: 0.0388 - mae: 0.0701 - val_loss: 0.0367 - val_mae: 0.0668
# Epoch 75/200
# 1244/1244 [==============================] - ETA: 0s - loss: 0.0363 - mae: 0.0660
# Epoch 75: val_loss did not improve from 0.03674
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0363 - mae: 0.0660 - val_loss: 0.0372 - val_mae: 0.0678
# Epoch 76/200
# 1243/1244 [============================>.] - ETA: 0s - loss: 0.0361 - mae: 0.0653
# Epoch 76: val_loss improved from 0.03674 to 0.03523, saving model to ./Saved_Models_Data/P40_U40_OA/best_enc_dec_3.h5
# 1244/1244 [==============================] - 14s 12ms/step - loss: 0.0361 - mae: 0.0653 - val_loss: 0.0352 - val_mae: 0.0648
# Epoch 77/200
# 1242/1244 [============================>.] - ETA: 0s - loss: 0.0355 - mae: 0.0643
# Epoch 77: val_loss did not improve from 0.03523
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0355 - mae: 0.0643 - val_loss: 0.0356 - val_mae: 0.0639
# Epoch 78/200
# 1242/1244 [============================>.] - ETA: 0s - loss: 0.0352 - mae: 0.0634
# Epoch 78: val_loss did not improve from 0.03523
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0352 - mae: 0.0634 - val_loss: 0.0361 - val_mae: 0.0643
# Epoch 79/200
# 1241/1244 [============================>.] - ETA: 0s - loss: 0.0349 - mae: 0.0629
# Epoch 79: val_loss improved from 0.03523 to 0.03468, saving model to ./Saved_Models_Data/P40_U40_OA/best_enc_dec_3.h5
# 1244/1244 [==============================] - 14s 12ms/step - loss: 0.0349 - mae: 0.0629 - val_loss: 0.0347 - val_mae: 0.0621
# Epoch 80/200
# 1242/1244 [============================>.] - ETA: 0s - loss: 0.0346 - mae: 0.0622
# Epoch 80: val_loss improved from 0.03468 to 0.03399, saving model to ./Saved_Models_Data/P40_U40_OA/best_enc_dec_3.h5
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0346 - mae: 0.0622 - val_loss: 0.0340 - val_mae: 0.0611
# Epoch 81/200
# 1240/1244 [============================>.] - ETA: 0s - loss: 0.0342 - mae: 0.0616
# Epoch 81: val_loss did not improve from 0.03399
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0342 - mae: 0.0616 - val_loss: 0.0343 - val_mae: 0.0617
# Epoch 82/200
# 1244/1244 [==============================] - ETA: 0s - loss: 0.0339 - mae: 0.0609
# Epoch 82: val_loss improved from 0.03399 to 0.03292, saving model to ./Saved_Models_Data/P40_U40_OA/best_enc_dec_3.h5
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0339 - mae: 0.0609 - val_loss: 0.0329 - val_mae: 0.0603
# Epoch 83/200
# 1243/1244 [============================>.] - ETA: 0s - loss: 0.0335 - mae: 0.0603
# Epoch 83: val_loss did not improve from 0.03292
# 1244/1244 [==============================] - 14s 12ms/step - loss: 0.0335 - mae: 0.0603 - val_loss: 0.0365 - val_mae: 0.0628
# Epoch 84/200
# 1244/1244 [==============================] - ETA: 0s - loss: 0.0334 - mae: 0.0597
# Epoch 84: val_loss did not improve from 0.03292
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0334 - mae: 0.0597 - val_loss: 0.0342 - val_mae: 0.0616
# Epoch 85/200
# 1240/1244 [============================>.] - ETA: 0s - loss: 0.0331 - mae: 0.0593
# Epoch 85: val_loss did not improve from 0.03292
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0331 - mae: 0.0593 - val_loss: 0.0331 - val_mae: 0.0595
# Epoch 86/200
# 1239/1244 [============================>.] - ETA: 0s - loss: 0.0329 - mae: 0.0588
# Epoch 86: val_loss did not improve from 0.03292
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0329 - mae: 0.0588 - val_loss: 0.0331 - val_mae: 0.0587
# Epoch 87/200
# 1244/1244 [==============================] - ETA: 0s - loss: 0.0383 - mae: 0.0651
# Epoch 87: val_loss did not improve from 0.03292
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0383 - mae: 0.0651 - val_loss: 0.0510 - val_mae: 0.0872
# Epoch 88/200
# 1244/1244 [==============================] - ETA: 0s - loss: 0.0361 - mae: 0.0648
# Epoch 88: val_loss did not improve from 0.03292
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0361 - mae: 0.0648 - val_loss: 0.0334 - val_mae: 0.0592
# Epoch 89/200
# 1244/1244 [==============================] - ETA: 0s - loss: 0.0991 - mae: 0.1448
# Epoch 89: val_loss did not improve from 0.03292
# 1244/1244 [==============================] - 15s 12ms/step - loss: 0.0991 - mae: 0.1448 - val_loss: 0.1006 - val_mae: 0.1721
# Epoch 90/200
# 1242/1244 [============================>.] - ETA: 0s - loss: 0.0883 - mae: 0.1668
# Epoch 90: val_loss did not improve from 0.03292
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0882 - mae: 0.1668 - val_loss: 0.0789 - val_mae: 0.1530
# Epoch 91/200
# 1241/1244 [============================>.] - ETA: 0s - loss: 0.0744 - mae: 0.1455
# Epoch 91: val_loss did not improve from 0.03292
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0744 - mae: 0.1455 - val_loss: 0.0715 - val_mae: 0.1456
# Epoch 92/200
# 1240/1244 [============================>.] - ETA: 0s - loss: 0.0658 - mae: 0.1314
# Epoch 92: val_loss did not improve from 0.03292
# 1244/1244 [==============================] - 14s 12ms/step - loss: 0.0658 - mae: 0.1314 - val_loss: 0.0636 - val_mae: 0.1301
# Epoch 93/200
# 1240/1244 [============================>.] - ETA: 0s - loss: 0.0619 - mae: 0.1228
# Epoch 93: val_loss did not improve from 0.03292
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0619 - mae: 0.1228 - val_loss: 0.0602 - val_mae: 0.1174
# Epoch 94/200
# 1244/1244 [==============================] - ETA: 0s - loss: 0.0589 - mae: 0.1156
# Epoch 94: val_loss did not improve from 0.03292
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0589 - mae: 0.1156 - val_loss: 0.0580 - val_mae: 0.1107
# Epoch 95/200
# 1240/1244 [============================>.] - ETA: 0s - loss: 0.0562 - mae: 0.1098
# Epoch 95: val_loss did not improve from 0.03292
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0562 - mae: 0.1098 - val_loss: 0.0598 - val_mae: 0.1114
# Epoch 96/200
# 1242/1244 [============================>.] - ETA: 0s - loss: 0.0542 - mae: 0.1046
# Epoch 96: val_loss did not improve from 0.03292
# 1244/1244 [==============================] - 13s 11ms/step - loss: 0.0542 - mae: 0.1046 - val_loss: 0.0531 - val_mae: 0.1025
# Epoch 97/200
# 1242/1244 [============================>.] - ETA: 0s - loss: 0.0521 - mae: 0.0996
# Epoch 97: val_loss did not improve from 0.03292
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0521 - mae: 0.0996 - val_loss: 0.0518 - val_mae: 0.0985
# Epoch 98/200
# 1244/1244 [==============================] - ETA: 0s - loss: 0.0510 - mae: 0.0965
# Epoch 98: val_loss did not improve from 0.03292
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0510 - mae: 0.0965 - val_loss: 0.0497 - val_mae: 0.0945
# Epoch 99/200
# 1242/1244 [============================>.] - ETA: 0s - loss: 0.0497 - mae: 0.0934
# Epoch 99: val_loss did not improve from 0.03292
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0497 - mae: 0.0934 - val_loss: 0.0483 - val_mae: 0.0913
# Epoch 100/200
# 1243/1244 [============================>.] - ETA: 0s - loss: 0.0490 - mae: 0.0913
# Epoch 100: val_loss did not improve from 0.03292
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0490 - mae: 0.0913 - val_loss: 0.0485 - val_mae: 0.0911
# Epoch 101/200
# 1243/1244 [============================>.] - ETA: 0s - loss: 0.0479 - mae: 0.0889
# Epoch 101: val_loss did not improve from 0.03292
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0479 - mae: 0.0889 - val_loss: 0.0483 - val_mae: 0.0904
# Epoch 102/200
# 1243/1244 [============================>.] - ETA: 0s - loss: 0.0471 - mae: 0.0869
# Epoch 102: val_loss did not improve from 0.03292
# 1244/1244 [==============================] - 14s 12ms/step - loss: 0.0471 - mae: 0.0869 - val_loss: 0.0472 - val_mae: 0.0863
# Epoch 103/200
# 1244/1244 [==============================] - ETA: 0s - loss: 0.0798 - mae: 0.1120
# Epoch 103: val_loss did not improve from 0.03292
# 1244/1244 [==============================] - 14s 12ms/step - loss: 0.0798 - mae: 0.1120 - val_loss: 0.1414 - val_mae: 0.1563
# Epoch 104/200
# 1242/1244 [============================>.] - ETA: 0s - loss: 0.1417 - mae: 0.1563
# Epoch 104: val_loss did not improve from 0.03292
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.1417 - mae: 0.1563 - val_loss: 0.1481 - val_mae: 0.1507
# Epoch 105/200
# 1243/1244 [============================>.] - ETA: 0s - loss: 0.1490 - mae: 0.1513
# Epoch 105: val_loss did not improve from 0.03292
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.1490 - mae: 0.1513 - val_loss: 0.1506 - val_mae: 0.1539
# Epoch 106/200
# 1241/1244 [============================>.] - ETA: 0s - loss: 0.1469 - mae: 0.1878
# Epoch 106: val_loss did not improve from 0.03292
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.1468 - mae: 0.1879 - val_loss: 0.1323 - val_mae: 0.2233
# Epoch 107/200
# 1242/1244 [============================>.] - ETA: 0s - loss: 0.1306 - mae: 0.2263
# Epoch 107: val_loss did not improve from 0.03292
# 1244/1244 [==============================] - 14s 12ms/step - loss: 0.1306 - mae: 0.2263 - val_loss: 0.1290 - val_mae: 0.2299
# Epoch 108/200
# 1241/1244 [============================>.] - ETA: 0s - loss: 0.1295 - mae: 0.2298
# Epoch 108: val_loss did not improve from 0.03292
# 1244/1244 [==============================] - 15s 12ms/step - loss: 0.1295 - mae: 0.2298 - val_loss: 0.1319 - val_mae: 0.2252
# Epoch 109/200
# 1242/1244 [============================>.] - ETA: 0s - loss: 0.1271 - mae: 0.2425
# Epoch 109: val_loss did not improve from 0.03292
# 1244/1244 [==============================] - 15s 12ms/step - loss: 0.1271 - mae: 0.2425 - val_loss: 0.1249 - val_mae: 0.2481
# Epoch 110/200
# 1242/1244 [============================>.] - ETA: 0s - loss: 0.1242 - mae: 0.2472
# Epoch 110: val_loss did not improve from 0.03292
# 1244/1244 [==============================] - 14s 12ms/step - loss: 0.1242 - mae: 0.2472 - val_loss: 0.1235 - val_mae: 0.2471
# Epoch 111/200
# 1244/1244 [==============================] - ETA: 0s - loss: 0.1225 - mae: 0.2446
# Epoch 111: val_loss did not improve from 0.03292
# 1244/1244 [==============================] - 14s 12ms/step - loss: 0.1225 - mae: 0.2446 - val_loss: 0.1211 - val_mae: 0.2412
# Epoch 112/200
# 1243/1244 [============================>.] - ETA: 0s - loss: 0.1016 - mae: 0.1938
# Epoch 112: val_loss did not improve from 0.03292
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.1016 - mae: 0.1938 - val_loss: 0.0842 - val_mae: 0.1564
# Epoch 113/200
# 1243/1244 [============================>.] - ETA: 0s - loss: 0.0786 - mae: 0.1506
# Epoch 113: val_loss did not improve from 0.03292
# 1244/1244 [==============================] - 14s 12ms/step - loss: 0.0786 - mae: 0.1506 - val_loss: 0.0757 - val_mae: 0.1434
# Epoch 114/200
# 1242/1244 [============================>.] - ETA: 0s - loss: 0.0745 - mae: 0.1423
# Epoch 114: val_loss did not improve from 0.03292
# 1244/1244 [==============================] - 14s 12ms/step - loss: 0.0745 - mae: 0.1423 - val_loss: 0.0731 - val_mae: 0.1380
# Epoch 115/200
# 1244/1244 [==============================] - ETA: 0s - loss: 0.0727 - mae: 0.1389
# Epoch 115: val_loss did not improve from 0.03292
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0727 - mae: 0.1389 - val_loss: 0.0718 - val_mae: 0.1409
# Epoch 116/200
# 1240/1244 [============================>.] - ETA: 0s - loss: 0.0696 - mae: 0.1326
# Epoch 116: val_loss did not improve from 0.03292
# 1244/1244 [==============================] - 14s 12ms/step - loss: 0.0696 - mae: 0.1326 - val_loss: 0.0655 - val_mae: 0.1251
# Epoch 117/200
# 1241/1244 [============================>.] - ETA: 0s - loss: 0.0735 - mae: 0.1328
# Epoch 117: val_loss did not improve from 0.03292
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0736 - mae: 0.1329 - val_loss: 0.0851 - val_mae: 0.1537
# Epoch 118/200
# 1243/1244 [============================>.] - ETA: 0s - loss: 0.0808 - mae: 0.1410
# Epoch 118: val_loss did not improve from 0.03292
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0808 - mae: 0.1410 - val_loss: 0.0760 - val_mae: 0.1319
# Epoch 119/200
# 1240/1244 [============================>.] - ETA: 0s - loss: 0.0756 - mae: 0.1311
# Epoch 119: val_loss did not improve from 0.03292
# 1244/1244 [==============================] - 14s 12ms/step - loss: 0.0758 - mae: 0.1312 - val_loss: 0.1380 - val_mae: 0.1626
# Epoch 120/200
# 1243/1244 [============================>.] - ETA: 0s - loss: 0.0645 - mae: 0.1203
# Epoch 120: val_loss did not improve from 0.03292
# 1244/1244 [==============================] - 14s 11ms/step - loss: 0.0645 - mae: 0.1203 - val_loss: 0.0623 - val_mae: 0.1142
# Epoch 121/200
# 1241/1244 [============================>.] - ETA: 0s - loss: 0.0600 - mae: 0.1130
# Epoch 121: val_loss did not improve from 0.03292
# 1244/1244 [==============================] - 14s 12ms/step - loss: 0.0600 - mae: 0.1130 - val_loss: 0.0577 - val_mae: 0.1086
# Epoch 122/200
# 1241/1244 [============================>.] - ETA: 0s - loss: 0.0579 - mae: 0.1086
# Epoch 122: val_loss did not improve from 0.03292
# 1244/1244 [==============================] - 14s 12ms/step - loss: 0.0579 - mae: 0.1085 - val_loss: 0.0558 - val_mae: 0.1050
# Epoch 122: early stopping

# %%
import numpy as np
import json
import matplotlib.pyplot as plt

save_path = "./Saved_Models_Data/P40_U40_OA/"
f = open(save_path+"history_3.json")
history = json.load(f)

# %%
# summarize history for loss
plt.plot(history['loss'])
plt.plot(history['val_loss'])
plt.title('Encoder Decoder Sequence Model P40_U40_OA loss (run 3)')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
#Evaluate the saved best model:
from tensorflow.keras.models import load_model
saved_model = load_model("./Saved_Models_Data/P40_U40_OA/best_enc_dec_3.h5")
best_eval = saved_model.evaluate(X_test_reshaped, Y_test_reshaped)

print("Mean Squared Error: ", best_eval[0])
print("Mean Absolute Error: ", best_eval[1])

#RMSE:
mse_value = best_eval[0]
rmse_value = np.sqrt(mse_value)
print("Root Mean Squared Error (RMSE): ", rmse_value)

# %%
save_path = "./Saved_Models_Data/P40_U40_OA/"

# %%
#Save the predictions
predictions = saved_model.predict(X_test_reshaped)
original_shape_predictions = predictions.reshape(X_test.shape[0], Y_test.shape[1])
np.save(save_path+"predictions_3.npy",original_shape_predictions)

#Save the ground truth:
np.save(save_path+"ground-truth_3.npy", Y_test)

# %%
save_path = "./Saved_Models_Data/P40_U40_OA/"

# %%
y_pred = np.load(save_path + "predictions_3.npy")
y_true = np.load(save_path + "ground-truth_3.npy")

# %%
#Print samples
print(y_pred.shape)
print(y_true.shape)
#Print some samples:
for sample in range(5):
    print(f"SAMPLE: {sample}")
    for i in range (81):
        print(f"Index {i} Ground truth: {y_true[sample][i]} Predicted: {y_pred[sample][i]}")

# %%
#Can convert to Benesh version for predictions using a threshold here = 0.5
print("Converting the predictions to benesh versions:")
benesh_arr = np.zeros_like(y_pred)

for sample in range(len(y_pred)):
  #print(f"SAMPLE: {sample}")
  for i in range (81):
    # can add more logic here to change the thresholds for specific indices.
    if y_pred[sample][i] >= 0.5:
      benesh_arr[sample][i] = 1
    elif y_pred[sample][i] < 0.5:
      benesh_arr[sample][i]= 0

print(benesh_arr[:2])
np.save(save_path+"y_pred_benesh_3.npy", benesh_arr)

# %%
#save the error array
y_pred = np.load(save_path+"predictions_3.npy")
y_true = np.load(save_path+"ground-truth_3.npy")

err_arr = np.zeros((12433,81))

for r in range(len(y_pred)):
    for c in range(81):
        err_arr[r][c] = abs(y_true[r][c]-y_pred[r][c])
        
np.save(save_path+"err_arr_3.npy",err_arr)

# %%
import seaborn as sns
err_arr = np.load(save_path+"err_arr_3.npy")
#fig, ax = plt.subplots(figsize=(18, 9))
plt.figure(figsize = (20,10))
sns.boxplot(err_arr, fliersize = 0.1 ,gap=0.05).set(title='Box Plot for Sequence Model EncDec_P40_U40_OA, showing error for each vector index (run 3)')
plt.show()

# %%
#Calculate MAPE
def mean_abs_perc_err(gt_arr, pred_arr, num_samples, vec_size):
    err_arr = np.zeros((num_samples,vec_size))
    print("Calculating MAPE")
    for r in range(len(pred_arr)):
        for c in range(vec_size):
          err_arr[r][c] = abs(gt_arr[r][c]-pred_arr[r][c]) # Calculation of the percentage error
    per_sample_mape_arr = np.sum(err_arr,axis=1)/vec_size
    print(per_sample_mape_arr.shape)
    print("MAPE for 10 samples...",per_sample_mape_arr[:10])
    overall_MAPE = sum(per_sample_mape_arr)/num_samples
    print("OVERALL MAPE: ", overall_MAPE*100) #multiplied by 100 for the results.

n_samples = 12433
v_size = 81
y_pred = np.load(save_path+"predictions_3.npy")
y_true = np.load(save_path+"ground-truth_3.npy")
mean_abs_perc_err(y_true,y_pred,n_samples,v_size)

# %%
from sklearn.metrics import r2_score

# %%
#Calculate R2 Score:
result_r2 = np.zeros(y_true.shape[0])

for i in range(y_true.shape[0]):
    # Calculate the R-squared value for each row
    r2 = r2_score(y_true[i, :], y_pred[i, :])
    result_r2[i] = r2

print("R-squared value for each row (sample):", result_r2)
# Calculate the overall R-squared value
overall_r2 = np.mean(result_r2)

# Print the overall R-squared value
print("Overall R-squared value:", overall_r2)

# %%
#Spearman Correlation:
result = np.zeros(y_true.shape[0])

for i in range(y_true.shape[0]):
    # Calculate the Spearman correlation for each row
    row_result = scipy.stats.spearmanr(y_true[i, :], y_pred[i, :])

    # Checking for zero standard deviation
    if np.isnan(row_result.correlation) or np.isnan(row_result.pvalue):
        # Handle the case where the result contains NaN
        result[i] = 0  # Set the correlation coefficient to 0
    else:
        result[i] = row_result.correlation

print("Spearman correlation coefficients for each row (sample):", result)
overall_spearman_corr = np.mean(result)

# Print the overall Spearman correlation coefficient
print("Overall Spearman correlation coefficient:", overall_spearman_corr)

# %%
#Pearson Correlation:
result_pearson = np.zeros(y_true.shape[0])

for i in range(y_true.shape[0]):
    # Calculate the Pearson correlation for each row
    corr_matrix = np.corrcoef(y_true[i, :], y_pred[i, :])
    result_pearson[i] = corr_matrix[0, 1]

# Calculate the overall Pearson correlation coefficient
overall_pearson_corr = np.mean(result_pearson)

print("Pearson correlation coefficients for each row:", result_pearson)
print(len(result_pearson))
# Print the overall Pearson correlation coefficient
print("Overall Pearson correlation coefficient:", overall_pearson_corr)

# %%
from sklearn.metrics import matthews_corrcoef
y_pred_b = np.load(save_path + "y_pred_benesh_3.npy")
y_true = np.load(save_path + "ground-truth_3.npy")

result_mcc = np.zeros(y_true.shape[0])

for i in range(y_true.shape[0]):
    # Calculate the Matthews Correlation Coefficient for each row
    mcc = matthews_corrcoef(y_true[i, :], y_pred_b[i, :])
    result_mcc[i] = mcc

# Calculate the overall Matthews Correlation Coefficient
overall_mcc = np.mean(result_mcc)

# Print the overall Matthews Correlation Coefficient
print("Overall Matthews Correlation Coefficient:", overall_mcc)

# %%
#Save boxplot stats
import numpy as np
save_path = "./Saved_Models_Data/P40_U40_OA/"

np.set_printoptions(suppress=True) # Disable scientific notation
filename = "err_arr_3.npy"

err = np.load(save_path+filename)
print(len(err))

stats = np.empty(shape = (0,5))
n_indices = len(err[0]) # should be 81
print(n_indices)

for i in range(n_indices):
    i_stats = np.percentile(err[:, i], [0, 25, 50, 75, 100]) # = [Min, Q1, Med, Q3, Max]
    stats = np.vstack([stats, i_stats]) # Add row to numpy stats object 
    print("index: {}".format(i), i_stats)

# print(stats)
out_filename = "boxplot_stats_3.csv"

np.savetxt(save_path+out_filename, stats, delimiter = ',', fmt='%f')
